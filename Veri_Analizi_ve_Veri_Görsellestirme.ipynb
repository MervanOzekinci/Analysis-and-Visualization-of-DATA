# %% [markdown]
# #Veriye ilk Bakis

# %%
import seaborn as sns
planets=sns.load_dataset('planets')

# %%
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
##veri setinin hikayesi nedir?

# %%
df=planets.copy()#bir kopyasini almak her zaman iyi olacaktir
#sonrasinda üzerinde degisiklik yapmak icin

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df.dtypes#veri setinin degiskenlerine ulasmak
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %%
import pandas as pd
df.method=pd.Categorical(df.method)

# %%
df.dtypes
# Out:
# method            category
# number               int64
# orbital_period     float64
# mass               float64
# distance           float64
# year                 int64
# dtype: object

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# #Veri Setinin Betimlenmesi

# %%
df.shape
# Out:
# (1035, 6)

# %%
df.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
df.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %%
df.describe(include='all').T #bütün degerleri al bak böyle bir kullanim mantikli olamz
#cunku eksik degerler var
# Out:
#                  count unique              top freq         mean  \
# method            1035     10  Radial Velocity  553          NaN
# number          1035.0    NaN              NaN  NaN     1.785507
# orbital_period   992.0    NaN              NaN  NaN  2002.917596
# mass             513.0    NaN              NaN  NaN     2.638161
# distance         808.0    NaN              NaN  NaN   264.069282
# year            1035.0    NaN              NaN  NaN  2009.070531
#
#                          std       min      25%      50%      75%       max
# method                   NaN       NaN      NaN      NaN      NaN       NaN
# number              1.240976       1.0      1.0      1.0      2.0       7.0
# orbital_period  26014.728304  0.090706  5.44254  39.9795  526.005  730000.0
# mass                3.818617    0.0036    0.229     1.26     3.04      25.0
# distance          733.116493      1.35    32.56    55.25    178.5    8500.0
# ...

# %%
#Eksik Degerlerin Incelenmesi

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# ##hic eksik gözlem var mi ?

# %%
df.isnull().values.any()#böylece veri setinde eksik bir gözlem olup olmadigina bakiyoruz
# Out:
# True

# %%
df.shape
# Out:
# (1035, 6)

# %% [markdown]
# ##hangi degiskende kacar tane eksik deger var?

# %%
df.isnull().sum()#hangi degerde kac tane eksik deger oldugunu gösterir
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df['orbital_period'].fillna(0,inplace=True)
#burada orbitaldaki eksik degelerin yerine 0 atadik

# %%
df.isnull().sum()
#eksik deger var mi diye baktigimizda yukaridaki kod ile olmadigini görecegiz
# Out:
# method              0
# number              0
# orbital_period      0
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df['mass'].fillna(df.mass.mean(),inplace=True)
#mass in eksik degerlerinin icine massin ortalama degerini atayarak
#massi eksik degerlerden kurtardik
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period      0
# mass                0
# distance          227
# year                0
# dtype: int64

# %%
df.fillna(df.mean(),inplace=True)
#burada da veri setinin bütün eksik degelerine
# o verinin ortalamasini atayarak eksik degerlernden kurtardik
df.isnull().sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# method            0
# number            0
# orbital_period    0
# mass              0
# distance          0
# year              0
# dtype: int64

# %%
df2=planets.copy()
df2.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# #Kategorik Degisken Özetleri

# %%
import seaborn as sns
planets=sns.load_dataset('planets')
df3=planets.copy()
df3.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# ##Sadece Kategorik Degiskenler ve Özetleri

# %%
kat_df=df3.select_dtypes(include=['object'])#sadece tipe göre secim yapmak

kat_df.head()
# Out:
#             method
# 0  Radial Velocity
# 1  Radial Velocity
# 2  Radial Velocity
# 3  Radial Velocity
# 4  Radial Velocity

# %%
kat_df.method.unique()#kac tane deger oldugunu dönder
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Transit Timing Variations',
#        'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#        'Pulsation Timing Variations'], dtype=object)

# %%
kat_df['method'].value_counts().count()#methodun toplamdaki degeri
#toplamda kac tane deger oldugnu saydirip döndürdük
# Out:
# 10

# %% [markdown]
# ##Kategorik Degiskenin Siniflarinin Frekanslarina Erismek

# %%
kat_df['method'].value_counts()#her birinden kac tane oldugunu göster
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %%
df3['method'].value_counts().plot.barh();#sutun grafigi seklinde görsellestirdik

# %%
#Sürekli Degisken Özetleri

# %%
import seaborn as sns
planets=sns.load_dataset('planets')
df=planets.copy()
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df_num=df.select_dtypes(include =['float64','int64'])

# %%
df_num
# Out:
#       number  orbital_period   mass  distance  year
# 0          1      269.300000   7.10     77.40  2006
# 1          1      874.774000   2.21     56.95  2008
# 2          1      763.000000   2.60     19.84  2011
# 3          1      326.030000  19.40    110.62  2007
# 4          1      516.220000  10.50    119.47  2009
# ...      ...             ...    ...       ...   ...
# 1030       1        3.941507    NaN    172.00  2006
# 1031       1        2.615864    NaN    148.00  2007
# 1032       1        3.191524    NaN    174.00  2007
# 1033       1        4.125083    NaN    293.00  2008
# 1034       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 5 columns]

# %%
df_num.describe().T
# Out:
#                  count         mean           std          min         25%  \
# number          1035.0     1.785507      1.240976     1.000000     1.00000
# orbital_period   992.0  2002.917596  26014.728304     0.090706     5.44254
# mass             513.0     2.638161      3.818617     0.003600     0.22900
# distance         808.0   264.069282    733.116493     1.350000    32.56000
# year            1035.0  2009.070531      3.972567  1989.000000  2007.00000
#
#                       50%       75%       max
# number             1.0000     2.000       7.0
# orbital_period    39.9795   526.005  730000.0
# mass               1.2600     3.040      25.0
# distance          55.2500   178.500    8500.0
# year            2010.0000  2012.000    2014.0

# %%
df_num['distance'].describe()#sadece distance i yorumlama
# Out:
# count     808.000000
# mean      264.069282
# std       733.116493
# min         1.350000
# 25%        32.560000
# 50%        55.250000
# 75%       178.500000
# max      8500.000000
# Name: distance, dtype: float64

# %%
print('ortalama:'+str(df_num['distance'].mean()))
print('Dolu Gözlem Sayisi:'+str(df_num['distance'].count()))
print('Maksimum Deger:'+str(df_num['distance'].max()))
print('Minimum Deger:'+str(df_num['distance'].min()))
print('Medyan: '+str(df_num['distance'].median()))
print('Standart Sapma'+str(df_num['distance'].std()))
# Out:
# ortalama:264.06928217821786
# Dolu Gözlem Sayisi:808
# Maksimum Deger:8500.0
# Minimum Deger:1.35
# Medyan: 55.25
# Standart Sapma733.1164929404422

# %% [markdown]
# #Dagilim Grafikleri

# %% [markdown]
# ##Barplot(sutun grafik)-eldeki kategorik degiskenleri görsellestirmek icin kullanilir

# %%
import seaborn as sns
diamonds=sns.load_dataset('diamonds')
df=diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ##veri setine hizli bakis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
df[df['price']>8000].value_counts()
# Out:
# carat  cut        color  clarity  depth  table  price  x      y      z
# 2.00   Good       G      SI2      64.3   60.0   10416  7.87   7.83   5.05    2
# 2.54   Very Good  H      SI2      63.5   56.0   16353  8.68   8.65   5.50    2
# 1.00   Premium    F      VVS2     60.6   54.0   8924   6.56   6.52   3.96    2
# 2.30   Premium    H      SI2      60.6   59.0   14042  8.40   8.37   5.08    2
# 2.66   Good       H      SI2      63.8   57.0   16239  8.71   8.65   5.54    2
#                                                                             ..
# 1.50   Very Good  G      SI2      63.1   57.0   9384   7.29   7.25   4.59    1
#                                                 9282   7.29   7.25   4.59    1
#                                   61.3   63.0   8148   7.28   7.23   4.45    1
#                                   60.7   61.0   8580   7.33   7.36   4.46    1
# 5.01   Fair       J      I1       65.5   59.0   18018  10.74  10.54  6.98    1
# Length: 7582, dtype: int64

# %%
df['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df['color'].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
#ordinal tanimlama
from pandas.api.types import CategoricalDtype

# %%
df.cut.head()
# Out:
# 0      Ideal
# 1    Premium
# 2       Good
# 3    Premium
# 4       Good
# Name: cut, dtype: category
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df.cut=df.cut.astype(CategoricalDtype(ordered=True))

# %%
df.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Ideal' < 'Premium' < 'Very Good' < 'Good' < 'Fair']

# %%
cut_categoriler=['Fair','Good','Very Good','Premium','Ideal']

# %%
df.cut=df.cut.astype(CategoricalDtype(categories=cut_categoriler, ordered=True))

# %%
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Fair' < 'Good' < 'Very Good' < 'Premium' < 'Ideal']

# %% [markdown]
# #barplot

# %%
df['cut'].value_counts().plot.barh().set_title('Cut Degiskeninin Sinif Frekansi')
# Out:
# Text(0.5, 1.0, 'Cut Degiskeninin Sinif Frekansi')

# %%
(df['cut']
 .value_counts()
 .plot.barh()
 .set_title('Cut Degiskeninin Sinif Frekansi'));
#program kodu cok uzun oldugunda parantez icinealip noktalardan itibaren 
#asagi yazarak kolay okunakli hale getirebiliriz
#en sondaki ; ise üstte cikan bilgiyi silmek icin kullanilir

# %%
sns.barplot(x='cut',y=df.cut.index,data=df);
#yukaridaki ile ayni sekil grafik olusturma ama daha kolay sekilde :)

# %% [markdown]
# #Caprazlamalar

# %%
import seaborn as sns
from pandas.api.types import CategoricalDtype
diamonds=sns.load_dataset('diamonds')
df=diamonds.copy()
cut_categoriler=['Fair','Good','Very Good','Premium','Ideal']
df.cut=df.cut.astype(CategoricalDtype(categories=cut_categoriler, ordered=True))
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x='cut',y='price',data=df);

# %%
sns.barplot(x='cut',y='price',hue='color',data=df);

# %%
sns.barplot(x='cut',y='price',color='blue',hue='color',data=df)

# %%
df.groupby(['cut','color'])['price'].mean()
# Out:
# cut        color
# Fair       D        4291.061350
#            E        3682.312500
#            F        3827.003205
#            G        4239.254777
#            H        5135.683168
#            I        4685.445714
#            J        4975.655462
# Good       D        3405.382175
#            E        3423.644159
#            F        3495.750275
#            G        4123.482204
#            H        4276.254986
#            I        5078.532567
#            J        4574.172638
# Very Good  D        3470.467284
#            E        3214.652083
#            F        3778.820240
#            G        3872.753806
#            H        4535.390351
#            I        5255.879568
#            J        5103.513274
# Premium    D        3631.292576
#            E        3538.914420
#            F        4324.890176
#            G        4500.742134
#            H        5216.706780
#            I        5946.180672
#            J        6294.591584
# ...

# %% [markdown]
# #Histogram ve Yogunluk

# %%
sns.distplot(df.price,kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# ?sns.distplot

# %%
sns.distplot(df.price, bins=1000,kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.price,hist=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(df.price, shade=True)

# %% [markdown]
# #Caprazlamalar

# %%
(sns
 .FacetGrid(df,
               hue='cut',
               height=5,
               xlim=(0,1000))
.map(sns.kdeplot,'price',shade=True)
.add_legend()
)

# %%
sns.catplot(x='cut',y='price',hue='color',kind='point',data=df);

# %% [markdown]
# #BOXPLOT

# %%
import seaborn as sns
tips=sns.load_dataset('tips')#tips:bahsis
df=tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df['sex'].value_counts()#toplamda hangi cinsiyetten kac kisi var
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
 df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# ##Boxplot Olusturulmasi

# %%
sns.boxplot(x=df['total_bill']);
#aykiri deger gözlemlenmesi icin en fazla yardimci olacak görsellerden biridir boxplot

# %% [markdown]
# ##Caprazlamalar

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ##hangi günler daha fazla bahsis kazniyoruz ona bakacagiz?

# %%
sns.boxplot(x='day',y='total_bill',data=df);

# %%
df['day'].value_counts()
#pazar günü daha az insan gelmesine ragmen daha fazla bahsis birakiliyor 
#belki de pazar günü özel günlerin bulusma vakitleridir?
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.boxplot(x='time',y='total_bill',data=df);
#hangi zamanda daha fazla bahsis birakiloyr bilgisi

# %%
sns.boxplot(x='sex',y='total_bill',data=df);
#hangi cinsiyetin daha fazla bahsis biraktigi bilgisi

# %%
sns.boxplot(x='size',y='total_bill',data=df);
#grup sayisina göre birakilan bahsis orani

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x='day', y='total_bill', hue='sex',data=df)

# %% [markdown]
# #Violin Grafiginin Olusturulmasi

# %%
###violun grafigi dagilim anlaminda görsel sunar
#tercihen kullanilabilir.

# %%
sns.catplot(y='total_bill', kind='violin',data=df)

# %% [markdown]
# ##Violin Grafik Caprazlamalar

# %%
sns.catplot(x='day',y='total_bill', kind='violin',data=df)

# %%
sns.catplot(x='day',y='total_bill',hue='sex', kind='violin',data=df)

# %% [markdown]
# #Korelasyon Grafiginin Olusturulmasi

# %%
import seaborn as sns
tips=sns.load_dataset('tips')
df=tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ##Scatterplot>>

# %%
sns.scatterplot(x='total_bill',y='tip',data=df);

# %% [markdown]
# ##Scatterplot Caprazlama

# %%
sns.scatterplot(x='total_bill',y='tip',hue='time',data=df);

# %%
sns.scatterplot(x='total_bill',y='tip',hue='time',style='time',data=df);

# %%
sns.scatterplot(x='total_bill',y='tip',hue='day',style='time',data=df);

# %%
sns.scatterplot(x='total_bill',y='tip',size='size',hue='size',data=df);

# %% [markdown]
# #Dogrusal Iliskinin Gösterilmesi

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lmplot(x='total_bill',y='tip',data=df);

# %%
sns.lmplot(x='total_bill',y='tip',hue='smoker',data=df);
#

# %%
sns.lmplot(x='total_bill',y='tip',hue='smoker',col='time',data=df);
#

# %%
sns.lmplot(x='total_bill',y='tip',hue='smoker',col='time',row='sex',data=df);
#

# %% [markdown]
# #Scatterplot Matrisi

# %%
import seaborn as sns
iris =sns.load_dataset('iris')
df=iris.copy()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
sns.pairplot(df);

# %%
sns.pairplot(df,hue='species');

# %%
sns.pairplot(df,hue='species',markers=['o','s','D']);

# %%
sns.pairplot(df,kind='reg',hue='species');
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-118-d4f1564ba2bb> in <module>()
# ----> 1 sns.pairplot(df,kind='reg',hue='species');
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2141     elif kind == "reg":
#    2142         from .regression import regplot  # Avoid circular import
# -> 2143         plotter(regplot, **plot_kws)
#    2144     elif kind == "kde":
# ...

# %% [markdown]
# #ISI HARITASI(HEAT-MAP)

# %% [markdown]
# ##Veri Seti Hikayesi>yillara ve aylara göre yolculuk veri seti

# %%
import seaborn as sns
flights=sns.load_dataset('flights')
df=flights.copy()
df.head()

# %%
df.shape

# %%
df['passengers'].describe()

# %%
df=df.pivot('month','year','passengers')

# %%
df

# %%
sns.heatmap(df);

# %%
sns.heatmap(df,annot=True,fmt='d')

# %%
sns.heatmap(df,annot=True,fmt='d',linewidths=0.5);

# %% [markdown]
# #Cizgi Grafik

# %% [markdown]
# ##Veri Seti Hikayesi
# beyne baglanan bir cihazla toplanan sinyalleri ifade eden bir veri seti

# %%
import seaborn as sns
fmri=sns.load_dataset('fmri')
df=fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df.shape
# Out:
# (1064, 5)

# %%
df['timepoint'].describe()
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
df['signal'].describe()
# Out:
# count    1064.000000
# mean        0.003540
# std         0.093930
# min        -0.255486
# 25%        -0.046070
# 50%        -0.013653
# 75%         0.024293
# max         0.564985
# Name: signal, dtype: float64

# %%
df.groupby('timepoint')['signal'].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %%
df.groupby('signal').count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
#  0.455575        1          1      1       1
#  0.460896        1          1      1       1
#  0.476055        1          1      1       1
#  0.494787        1          1      1       1
#  0.564985        1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df.groupby('timepoint')['signal'].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# timepoint
# 0           56.0 -0.016662  0.028326 -0.064454 -0.039169 -0.018382  0.003539
# 1           56.0 -0.025002  0.030641 -0.082174 -0.046299 -0.024533 -0.005388
# 2           56.0 -0.012873  0.035440 -0.110565 -0.034944 -0.013183  0.009318
# 3           56.0  0.034446  0.058260 -0.089708 -0.001157  0.028430  0.061840
# 4           56.0  0.098194  0.092838 -0.046347  0.030912  0.070166  0.144911
# 5           56.0  0.137725  0.123353 -0.017946  0.042762  0.096535  0.211638
# 6           56.0  0.127515  0.137332 -0.054405  0.022409  0.068850  0.218919
# 7           56.0  0.075660  0.129704 -0.108222 -0.016252  0.032486  0.144781
# 8           56.0  0.013420  0.104216 -0.181241 -0.049453 -0.012834  0.030396
# 9           56.0 -0.032041  0.072728 -0.152929 -0.075693 -0.038496  0.008717
# 10          56.0 -0.053685  0.053148 -0.176453 -0.078893 -0.052906 -0.015302
# ...

# %%
sns.lineplot(x='timepoint',y='signal',data=df);

# %%
sns.lineplot(x='timepoint',y='signal',hue='event',data=df);

# %%
sns.lineplot(x='timepoint',y='signal',hue='event',data=df,style='event');

# %%
sns.lineplot(x='timepoint',
             y='signal',
             hue='event',
             data=df,
             style='event',
             markers=True,
             dashes=False);

# %%
sns.lineplot(x='timepoint',
             y='signal',
             hue='region',

             data=df,
             style='event',
             markers=True,
             dashes=False);

# %% [markdown]
# #Basit Zaman Serisi Grafigi

# %%
import pandas_datareader as pr
